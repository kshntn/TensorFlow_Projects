# %%
import tensorflow as tf
from tensorflow import keras

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
mnist=keras.datasets.fashion_mnist

# %%
(x_train,y_train),(x_test,y_test)=mnist.load_data()

# %%
x_train.shape
# Out:
# (60000, 28, 28)

# %%
class_name=['top','trouser','pullover','dress','coat','sandal','shirt','sneaker','bag','ankle boot']

# %%
image=1
plt.figure()
plt.imshow(x_train[image])
print(y_train[image])
plt.colorbar()
# Out:
# 0

# %% [markdown]
# Normalizing

# %%
x_train=x_train/255.0
x_test=x_test/255.0

# %%
image=1
plt.figure()
plt.imshow(x_train[image])
print(y_train[image])
plt.colorbar()
# Out:
# 0

# %% [markdown]
# Model build

# %%
from tensorflow.keras import  Sequential
from tensorflow.keras.layers import  Flatten,Dense

# %%
model=Sequential()
model.add(Flatten(input_shape=(28,28)))
model.add(Dense(128,activation='relu'))
model.add(Dense(10,activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 784)               0
# _________________________________________________________________
# dense (Dense)                (None, 128)               100480
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 101,770
# Trainable params: 101,770
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
model.fit(x_train,y_train,epochs=10)
# Out:
# Train on 60000 samples
# Epoch 1/10
# 60000/60000 [==============================] - 7s 117us/sample - loss: 0.5033 - accuracy: 0.8232
# Epoch 2/10
# 60000/60000 [==============================] - 6s 96us/sample - loss: 0.3776 - accuracy: 0.8645
# Epoch 3/10
# 60000/60000 [==============================] - 6s 93us/sample - loss: 0.3379 - accuracy: 0.8774
# Epoch 4/10
# 60000/60000 [==============================] - 6s 96us/sample - loss: 0.3149 - accuracy: 0.8848
# Epoch 5/10
# 60000/60000 [==============================] - 6s 94us/sample - loss: 0.2957 - accuracy: 0.8906
# Epoch 6/10
# 60000/60000 [==============================] - 6s 94us/sample - loss: 0.2813 - accuracy: 0.8969
# Epoch 7/10
# 60000/60000 [==============================] - 6s 95us/sample - loss: 0.2694 - accuracy: 0.8999
# Epoch 8/10
# 60000/60000 [==============================] - 6s 95us/sample - loss: 0.2558 - accuracy: 0.9046
# Epoch 9/10
# 60000/60000 [==============================] - 6s 96us/sample - loss: 0.2489 - accuracy: 0.9068
# Epoch 10/10
# 60000/60000 [==============================] - 6s 96us/sample - loss: 0.2388 - accuracy: 0.9104

# %%
test_loss,test_acc=model.evaluate(x_test,y_test)
print(test_acc)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# 0.8778

# %%
from sklearn.metrics import accuracy_score

# %%
y_pred=model.predict_classes(x_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.8778

# %%
pred=model.predict(x_test)

# %%
pred
# Out:
# array([[2.1696600e-05, 2.2690979e-06, 1.3299444e-07, ..., 5.7101149e-02,
#         1.8656209e-04, 9.4012898e-01],
#        [1.8703906e-05, 4.3091321e-14, 9.9886847e-01, ..., 7.1541186e-19,
#         1.1188141e-11, 5.4934496e-16],
#        [4.8030686e-09, 1.0000000e+00, 7.8247450e-11, ..., 2.1799739e-21,
#         1.7296585e-15, 2.3284312e-17],
#        ...,
#        [1.4583487e-04, 1.2719796e-10, 6.8290246e-05, ..., 3.3403394e-10,
#         9.9972719e-01, 2.0249392e-11],
#        [1.3688606e-07, 9.9999261e-01, 1.1124810e-07, ..., 5.4976568e-17,
#         1.0708925e-09, 2.7949513e-12],
#        [2.3647952e-05, 2.0845384e-08, 4.8929119e-06, ..., 4.5041693e-03,
#         1.4905903e-03, 6.8179793e-06]], dtype=float32)

# %%
pred[0]
# Out:
# array([2.1696600e-05, 2.2690979e-06, 1.3299444e-07, 1.6508578e-09,
#        3.3064000e-05, 2.5182439e-03, 7.9205483e-06, 5.7101149e-02,
#        1.8656209e-04, 9.4012898e-01], dtype=float32)

# %%
np.argmax(pred[0])
# Out:
# 9

# %%
image=0
plt.figure()
plt.imshow(x_test[image])
print(y_test[image])
plt.colorbar()
# Out:
# 9
